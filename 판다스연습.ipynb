# %% [markdown]
# <a href="https://colab.research.google.com/github/swoopro/big/blob/master/%ED%8C%90%EB%8B%A4%EC%8A%A4%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('코랩에 오신것을 환영합니다.')

# 실행만! 컨트롤+enter
# 실행하고 다음 입력할 화면 자동으로 만든다! 쉬프트+enter
# Out:
# 코랩에 오신것을 환영합니다.

# %%
print("나는 자동완성 됩니다. tab 또는 ctrl+space bar")
# Out:
# 나는 자동완성 됩니다. tab 또는 ctrl+space bar

# %%
# 하나 하나의 입력창 : cell

# %%
temp = '임시 데이터'
temp
# Out:
# '임시 데이터'

# %%
import requests

# %%
# !pip install bs4 설치안되있으면 이렇게하면댐
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/item/main.nhn?code=028300"
url
# Out:
# 'https://finance.naver.com/item/main.nhn?code=028300'

# %%
site = requests.get(url)
site
# Out:
# <Response [200]>

# %%
# Response 200 : 응답 잘 받았다는 메세지
content = BeautifulSoup(site.content, "html.parser")
content
# Out:
# <html lang="ko">
# <head>
# <title>에이치엘비 : 네이버 금융</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="https://finance.naver.com/item/main.nhn?code=028300" property="og:url">
# <meta content="에이치엘비 - 네이버 금융 : 네이버 금융" property="og:title">
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버금융" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="/css/finance_header.css?20190903164201" rel="stylesheet" type="text/css"/>
# ...

# %%
no_today = content.find("p", {"class":"no_today"})
no_today
# Out:
# <p class="no_today">
# <em class="no_up">
# <span class="blind">180,800</span>
# <span class="no1">1</span><span class="no8">8</span><span class="no0">0</span><span class="shim">,</span><span class="no8">8</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# </p>

# %%
blind_now = no_today.find("span", {"class": "blind"})
blind_now
# Out:
# <span class="blind">180,800</span>

# %%
print("최종 결과값: ", blind_now.text)
# Out:
# 최종 결과값:  180,800
